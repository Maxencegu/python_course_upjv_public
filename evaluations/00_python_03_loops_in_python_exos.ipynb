# %% [markdown]
# ---
#
# <center>
#
# # **Python for Data Science**
#
# ### *Loops in python*
#
# </center>
#
# ---

# %% [markdown]
# ## ⚙️ Initialization
#
# ---
#
# Before starting, please **run the following cell once** to initialize the tests.
# You need to do this **every time you open the notebook** (this loads the hidden tests).
#
# > ✅ Then, for each exercise, you can click on the "Launch test" button.

# %%
# @title Initialization - Execute this cell ONCE at the start
# ⚠️ DON'T MODIFY THIS CODE
import os
from IPython.display import display, Markdown,HTML
from google.colab import output
import subprocess

# Remove the old hidden_tests file if it exists
if os.path.exists("hidden_tests_00_python_03.py"):
    os.remove("hidden_tests_00_python_03.py")

# Download the latest version every time
import subprocess
subprocess.run([
    "wget", "-q",
    "https://raw.githubusercontent.com/Maxencegu/python_course_upjv_public/main/evaluations/hidden_tests_00_python_03.py"
])

# Import the test functions
from hidden_tests_00_python_03 import hidden_test_exo1, hidden_test_exo2, hidden_test_exo3, hidden_test_exo4

# Generic callback function to run the test corresponding to the exercise name
def _run_test(exo_name):
    try:
        g = globals()  # get student's variables dynamically
        if exo_name == 'exo1':
            result = hidden_test_exo1(g['my_numbers'], g['the_sum'])
        elif exo_name == 'exo2':
            result = hidden_test_exo2(g['n'], g['multiples'])
        elif exo_name == 'exo3':
            result = hidden_test_exo3(g['the_values'])
        elif exo_name == 'exo4':
            result = hidden_test_exo4(g['limit'], g['num_primes'])
        else:
            result = "❌ Unknown exercise."
        display(Markdown(result))
    except NameError as e:
        display(Markdown(f"❌ Missing variable: `{e}`"))
    except Exception as e:
        display(Markdown(f"❌ Error while running test for {exo_name}: `{e}`"))

# Register the callback in Colab
output.register_callback('notebook.runTest', _run_test)

print("✅ Initialization complete! You can now run your exercises and test them using the buttons below each exercise.")
# Out:
# ✅ Initialization complete! You can now run your exercises and test them using the buttons below each exercise.

# %% [markdown]
# ---
#
# <center>
#
# ## **Loops in python**
#
# </center>
#
# ---

# %%
# @title Exercise 1 (Easy) – Counting with a For Loop

# (a) Create a variable numbers containing 5 numbers.
# (b) Use a for loop to print each number in the list.
# (c) Store the sum of all numbers in a variable.

# Student code starts here

# Student code ends here

# DON'T MODIFY THIS CODE :
# Button to launch tests for this exercise
print()
from IPython.display import display, HTML
display(HTML('''
    <button onclick="google.colab.kernel.invokeFunction('notebook.runTest', ['exo1'], {})">
        ✅ Run test for exercise 1
    </button>
'''))
# Out:
#     <button onclick="google.colab.kernel.invokeFunction('notebook.runTest', ['exo1'], {})">
#         ✅ Run test for exercise 1
#     </button>

# %%
# @title Exercise 2 (Medium) – Multiplication Table

# (a) Create a variable with a number.
# (b) Use a for loop to print the multiplication table of this variable from 1 to X.
# (c) Store all results inside a list.

# Student code ends here

# Student code ends here

# DON'T MODIFY THIS CODE :
# Button to launch tests for this exercise
print()
from IPython.display import display, HTML
display(HTML('''
    <button onclick="google.colab.kernel.invokeFunction('notebook.runTest', ['exo2'], {})">
        ✅ Run test for exercise 2
    </button>
'''))
# Out:
#     <button onclick="google.colab.kernel.invokeFunction('notebook.runTest', ['exo2'], {})">
#         ✅ Run test for exercise 2
#     </button>

# %%
# @title Exercise 3 (Intermediate) – While Loop & Conditions

# (a) Create a variable count.
# (b) Using a while loop, keep adding 2 to count until it reaches or exceeds a value.
# (c) Store the values generated during the loop inside a list.

# Student code starts here

# Student code ends here

# DON'T MODIFY THIS CODE :
# Button to launch tests for this exercise
print()
from IPython.display import display, HTML
display(HTML('''
    <button onclick="google.colab.kernel.invokeFunction('notebook.runTest', ['exo3'], {})">
        ✅ Run test for exercise 3
    </button>
'''))
# Out:
#     <button onclick="google.colab.kernel.invokeFunction('notebook.runTest', ['exo3'], {})">
#         ✅ Run test for exercise 3
#     </button>

# %%
# @title Exercise 4 (Hard) – Prime Numbers with Loops

# (a) Create a variable max.
# (b) Using a for loop and an inner loop (or condition), generate all prime numbers up to max.
# (c) Store them inside a list

# Student code starts here

# Student code ends here

# DON'T MODIFY THIS CODE :
# Button to launch tests for this exercise
print()
from IPython.display import display, HTML
display(HTML('''
    <button onclick="google.colab.kernel.invokeFunction('notebook.runTest', ['exo4'], {})">
        ✅ Run test for exercise 4
    </button>
'''))
# Out:
#     <button onclick="google.colab.kernel.invokeFunction('notebook.runTest', ['exo4'], {})">
#         ✅ Run test for exercise 4
#     </button>
