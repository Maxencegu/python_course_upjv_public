# %% [markdown]
# ---
#
# <center>
#
# # **Python for Data Science**
#
# ### *Classes and modules*
#
# </center>
#
# ---

# %% [markdown]
# ## ⚙️ Initialization
#
# ---
#
# Before starting, please **run the following cell once** to initialize the tests.
# You need to do this **every time you open the notebook** (this loads the hidden tests).
#
# > ✅ Then, for each exercise, you can click on the "Launch test" button.

# %%
# @title Initialization - Execute this cell ONCE at the start
# ⚠️ DON'T MODIFY THIS CODE
import os
from IPython.display import display, Markdown,HTML
from google.colab import output
import subprocess

# Remove the old hidden_tests file if it exists
if os.path.exists("hidden_tests_01_pandas_01.py"):
    os.remove("hidden_tests_01_pandas_01.py")

# Download the latest version every time
import subprocess
subprocess.run([
    "wget", "-q",
    "https://raw.githubusercontent.com/Maxencegu/python_course_upjv_public/main/evaluations/hidden_tests_01_pandas_01.py"
])

# Import the test functions
from hidden_tests_01_pandas_01 import hidden_test_exo1, hidden_test_exo2, hidden_test_exo3, hidden_test_exo4

# Generic callback function to run the test corresponding to the exercise name
def _run_test(exo_name):
    try:
        g = globals()  # get student's variables dynamically
        if exo_name == 'exo1':
            result = hidden_test_exo1(g['df'])
        elif exo_name == 'exo2':
            result = hidden_test_exo2(g['df_csv'])
        elif exo_name == 'exo3':
            result = hidden_test_exo3(g['names'], g['row_1'], g['filtered'])
        elif exo_name == 'exo4':
            result = hidden_test_exo4(g['summary'], g['mean_score'])
        else:
            result = "❌ Unknown exercise."
        display(Markdown(result))
    except NameError as e:
        display(Markdown(f"❌ Missing variable: `{e}`"))
    except Exception as e:
        display(Markdown(f"❌ Error while running test for {exo_name}: `{e}`"))

# Register the callback in Colab
output.register_callback('notebook.runTest', _run_test)

print("✅ Initialization complete! You can now run your exercises and test them using the buttons below each exercise.")
# Out:
# ✅ Initialization complete! You can now run your exercises and test them using the buttons below each exercise.

# %% [markdown]
# ---
#
# <center>
#
# ## **Pandas - Getting Started With DataFrames**
#
# </center>
#
# ---

# %%
# @title Exercise 1 (Easy) – Create a DataFrame from a Dictionary

# (a) Import pandas
# (b) Create a dictionary data with keys "Name" and "Age" and 3 values.
# (c) Create a DataFrame from the dictionary.
# (d) Display the DataFrame.

# Student code starts here

# Student code ends here

# DON'T MODIFY THIS CODE :
# Button to launch tests for this exercise
print()
from IPython.display import display, HTML
display(HTML('''
    <button onclick="google.colab.kernel.invokeFunction('notebook.runTest', ['exo1'], {})">
        ✅ Run test for exercise 1
    </button>
'''))
# Out:
#     <button onclick="google.colab.kernel.invokeFunction('notebook.runTest', ['exo1'], {})">
#         ✅ Run test for exercise 1
#     </button>

# %%
# @title Exercise 2 (Medium) – Create a DataFrame from a CSV

# (a) Create a CSV file named "students.csv" with columns "Name" and "Score" and 6 rows: Alice, 55, ...
# To create a csv with python :
# import csv
# with open("students.csv", "w", newline="") as f:
#    writer = csv.writer(f)
#    writer.writerow(["Name", "Score"])
#    writer.writerow(["Alice", 55])
#    ...

# (b) Load the CSV into a DataFrame df_csv using pd.read_csv().
# (c) Display the DataFrame.

# Student code ends here

# Student code ends here

# DON'T MODIFY THIS CODE :
# Button to launch tests for this exercise
print()
from IPython.display import display, HTML
display(HTML('''
    <button onclick="google.colab.kernel.invokeFunction('notebook.runTest', ['exo2'], {})">
        ✅ Run test for exercise 2
    </button>
'''))
# Out:
#     <button onclick="google.colab.kernel.invokeFunction('notebook.runTest', ['exo2'], {})">
#         ✅ Run test for exercise 2
#     </button>

# %%
# @title Exercise 3 (Intermediate) – Select and Filter Rows/Columns

# (a) Use the df DataFrame from Exercise 2.
# (b) Select the "Name" column and store it.
# (c) Select the row with index 2 store it.
# (d) Filter rows where "Score" > 58 and store in.

# Student code starts here

# Student code ends here

# DON'T MODIFY THIS CODE :
# Button to launch tests for this exercise
print()
from IPython.display import display, HTML
display(HTML('''
    <button onclick="google.colab.kernel.invokeFunction('notebook.runTest', ['exo3'], {})">
        ✅ Run test for exercise 3
    </button>
'''))
# Out:
#     <button onclick="google.colab.kernel.invokeFunction('notebook.runTest', ['exo3'], {})">
#         ✅ Run test for exercise 3
#     </button>

# %%
# @title Exercise 4 (Hard) – DataFrame Overview and Describe

# (a) Use the DataFrame from Exercise 2.
# (b) Compute a quick statistical summary of the "Score" column.
# (c) Calcul the mean and the min/max score.

# Student code starts here

# Student code ends here

# DON'T MODIFY THIS CODE :
# Button to launch tests for this exercise
print()
from IPython.display import display, HTML
display(HTML('''
    <button onclick="google.colab.kernel.invokeFunction('notebook.runTest', ['exo4'], {})">
        ✅ Run test for exercise 4
    </button>
'''))
# Out:
#     <button onclick="google.colab.kernel.invokeFunction('notebook.runTest', ['exo4'], {})">
#         ✅ Run test for exercise 4
#     </button>
